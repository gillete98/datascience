# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %% [markdown]
# ###1. 10 countries with the lowest infant mortality rates

# %%
#root
mondial = document.getroot()

# %%
mondial.tag
# Out:
# 'mondial'

# %%
mondial.attrib
# Out:
# {}

# %%
# Create a list.
elements = []
#for child in root:
for country in mondial:
    #print country.tag, country.attrib, country.text
    infantmor = None
    #i += 1
    for node in country.getchildren():
        #print node.tag, node.attrib, node.text, node.tail        
        if node.tag == 'name':
            name = node.text
        elif node.tag == 'infant_mortality':
            infantmor = node.text
    if infantmor is not None:
        # Append tuples
        elements.append((name,float(infantmor) ))
        #print name, infantmor

#Sort tuples inside list
elements.sort(key=lambda tup: tup[1])
print ("Top Ten with lowest infant mortality")
print ('Country     Rate')
for i in range(0,10):
    #print('Country ' + elements[i][0] + '-' + 'rate '+ str(elements[i][1]) )
    print(elements[i][0] + '    ' + str(elements[i][1]) )
# Out:
# Top Ten with lowest infant mortality
# Country     Rate
# Monaco    1.81
# Japan    2.13
# Norway    2.48
# Bermuda    2.48
# Singapore    2.53
# Sweden    2.6
# Czech Republic    2.63
# Hong Kong    2.73
# Macao    3.13
# Iceland    3.15

# %% [markdown]
# ###2. 10 cities with the largest population

# %%
# Create a list.
elements = []
#for child in root:
for country in mondial:
    #print country.tag, country.attrib, country.text
    year1 = 0
    for node in country.getchildren():
        #print node.tag, node.attrib, node.text, node.tail        
        if node.tag == 'name':
            name = node.text
        elif node.tag == 'population':
            #Attribute is a dictionary
            year2 = int(node.attrib['year'])
            if year2 > year1:
                population = node.text
                year1 = year2
    if year1 > 0:
        # Append tuples
        elements.append((name,float(population), int(year2) ))
        #print name, infantmor

#Sort tuples inside list
elements.sort(key=lambda tup: tup[1], reverse=True)
print ("Top Ten with largest population")
print ('Country     Population    Year')
for i in range(0,10):
    #print('Country ' + elements[i][0] + '-' + 'rate '+ str(elements[i][1]) )
    print(elements[i][0] + '    ' + str(elements[i][1]) + '    ' + str(elements[i][2]) )
# Out:
# Top Ten with largest population
# Country     Population    Year
# China    1360720000.0    2013
# India    1210854977.0    2011
# United States    318857056.0    2014
# Indonesia    252124458.0    2014
# Brazil    202768562.0    2014
# Pakistan    173149306.0    2010
# Nigeria    164294516.0    2011
# Bangladesh    149772364.0    2011
# Russia    143666931.0    2014
# Japan    127298000.0    2013

# %% [markdown]
# ###3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)

# %%
# Create a list.
elements = []
#for child in root:
for country in mondial:
    #print country.tag, country.attrib, country.text
    year1 = 0
    for node in country.getchildren():
        #print node.tag, node.attrib, node.text, node.tail        
        if node.tag == 'name':
            name = node.text
        elif node.tag == 'population':
            #Attribute is a dictionary
            year2 = int(node.attrib['year'])
            if year2 > year1:
                population = int(node.text)
                year1 = year2
        elif node.tag == 'ethnicgroup': 
            eth_name = node.text
            eth_per = float(node.attrib['percentage'])
            eth_pop = (population*eth_per/100)
            elements.append((name,population, int(year2),eth_name, int(eth_pop) ))            

#Sort tuples inside list
elements.sort(key=lambda tup: tup[4], reverse=True)
print ("Top Ten ethnic groups")
print ('Country     Population    Year    EthnicGroup     EthnicPopulation')
for i in range(0,10):
    print(elements[i][0] + '    ' + str(elements[i][1]) + '    ' + str(elements[i][2])+ '    ' + str(elements[i][3])+ '    ' + str(elements[i][4]) )
# Out:
# Top Ten ethnic groups
# Country     Population    Year    EthnicGroup     EthnicPopulation
# China    1360720000    2013    Han Chinese    1245058800
# India    1210854977    2011    Indo-Aryan    871815583
# India    1210854977    2011    Dravidian    302713744
# United States    318857056    2014    European    254958101
# Nigeria    164294516    2011    African    162651570
# Bangladesh    149772364    2011    Bengali    146776916
# Japan    127298000    2013    Japanese    126534212
# Russia    143666931    2014    Russian    114646210
# Indonesia    252124458    2014    Javanese    113456006
# Brazil    202768562    2014    European    108886717

# %% [markdown]
# ###4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
#Iterate nodes including. Best way to filter by markup
#rivers = document.find( 'users' )
# Create a list.
elements = []
#for child in root:
for river in document.findall( 'river' ): #tag name
    country_name = river.attrib['country']
    for node in river.getchildren():
        if node.tag== 'name':
            river_name = node.text
        elif node.tag == 'length':
            river_length= float(node.text)
    elements.append((country_name,river_name, float(river_length) ))    

#Sort by longest river
elements.sort(key=lambda tup: tup[2], reverse=True)
print ("Longest River")
print ('Country     River    Length')
for i in range(0,1):
    print(elements[i][0] + '    ' + str(elements[i][1]) + '    ' + str(elements[i][2]) )
# Out:
# Longest River
# Country     River    Length
# CO BR PE    Amazonas    6448.0

# %%
#Iterate nodes including. Best way to filter by markup
#rivers = document.find( 'users' )
# Create a list.
elements = []

#for child in root:
for lake in document.findall( 'lake' ): #tag name
    country_name = lake.attrib['country']
    for node in lake.getchildren():
        if node.tag== 'name':
            lake_name = node.text
        elif node.tag == 'area':
            lake_area= float(node.text)
    elements.append((country_name,lake_name, float(lake_area) ))    

#Sort by longest river
elements.sort(key=lambda tup: tup[2], reverse=True)
print ("Largest Lake")
print ('Country     Lake    Area')
for i in range(0,1):
    print(elements[i][0] + '    ' + str(elements[i][1]) + '    ' + str(elements[i][2]) )
# Out:
# Largest Lake
# Country     Lake    Area
# R AZ KAZ IR TM    Caspian Sea    386400.0

# %%
#Iterate nodes including. Best way to filter by markup
#rivers = document.find( 'users' )
# Create a list.
elements = []
#for child in root:
for airport in document.findall( 'airport' ): #tag name
    country_name = airport.attrib['country']
    for node in airport.getchildren():
        if node.tag== 'name':
            airport_name = node.text
        elif node.tag == 'elevation':
            if node.text > 0:
                airport_elevation = node.text 
            else:
                airport_elevation= 0
            
            
    elements.append((country_name,airport_name, int(airport_elevation) ))    

#Sort by longest river
elements.sort(key=lambda tup: tup[2], reverse=True)
print ("Highest Airport")
print ('Country     Airport    Elevation')
for i in range(0,1):
    print(elements[i][0] + '    ' + str(elements[i][1]) + '    ' + str(elements[i][2]) )
# Out:
# Highest Airport
# Country     Airport    Elevation
# BOL    El Alto Intl    4063

# %% [markdown]
# ###Test Area

# %%
#Iterate nodes including
#rivers = document.find( 'users' )
# Create a list.
elements = []
#for child in root:
for river in document.findall( 'airport' ): #tag name
    print river.tag, river.attrib
    for node in river.getchildren():
        print '-', node.tag, '-', node.attrib ,'-', node.text
# Out:
# airport {'city': 'cty-Afghanistan-2', 'iatacode': 'HEA', 'country': 'AFG'}
# - name - {} - Herat
# - latitude - {} - 34.210017
# - longitude - {} - 62.2283
# - elevation - {} - 977
# - gmtOffset - {} - 5
# airport {'city': 'cty-Afghanistan-Kabul', 'iatacode': 'KBL', 'country': 'AFG'}
# - name - {} - Kabul Intl
# - latitude - {} - 34.565853
# - longitude - {} - 69.212328
# - elevation - {} - 1792
# - gmtOffset - {} - 5
# airport {'city': 'cty-Albania-Tirane', 'iatacode': 'TIA', 'country': 'AL'}
# - name - {} - Tirana Rinas
# - latitude - {} - 41.414742
# - longitude - {} - 19.720561
# - elevation - {} - 38
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-14', 'iatacode': 'TEE', 'country': 'DZ'}
# - name - {} - Cheikh Larbi Tebessi
# - latitude - {} - 35.431611
# - longitude - {} - 8.120717
# - elevation - {} - 811
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-6', 'iatacode': 'BLJ', 'country': 'DZ'}
# - name - {} - Batna Airport
# - latitude - {} - 35.752106
# - longitude - {} - 6.308589
# - elevation - {} - 822
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-11', 'iatacode': 'BJA', 'country': 'DZ'}
# - name - {} - Soummam
# - latitude - {} - 36.711997
# - longitude - {} - 5.069922
# - elevation - {} - 6
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-19', 'iatacode': 'TMR', 'country': 'DZ'}
# - name - {} - Tamanrasset
# - latitude - {} - 22.811461
# - longitude - {} - 5.451075
# - elevation - {} - 1377
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-17', 'iatacode': 'BSK', 'country': 'DZ'}
# - name - {} - Biskra
# - latitude - {} - 34.793289
# - longitude - {} - 5.738231
# - elevation - {} - 88
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-4', 'iatacode': 'CZL', 'country': 'DZ'}
# - name - {} - Mohamed Boudiaf Intl
# - latitude - {} - 36.276028
# - longitude - {} - 6.620386
# - elevation - {} - 691
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-7', 'iatacode': 'QSF', 'country': 'DZ'}
# - name - {} - Ain Arnat Airport
# - latitude - {} - 36.1781
# - longitude - {} - 5.32449
# - elevation - {} - 1024
# - gmtOffset - {} - 0
# airport {'city': 'cty-Algeria-3', 'iatacode': 'ORN', 'country': 'DZ'}
# - name - {} - Es Senia
# - latitude - {} - 35.623858
# - longitude - {} - -0.621183
# - elevation - {} - 90
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-21', 'iatacode': 'GHA', 'country': 'DZ'}
# - name - {} - Noumerat
# - latitude - {} - 32.384106
# - longitude - {} - 3.794114
# - elevation - {} - 461
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-5', 'iatacode': 'AAE', 'country': 'DZ'}
# - name - {} - Annaba
# - latitude - {} - 36.822225
# - longitude - {} - 7.809167
# - elevation - {} - 5
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-Algiers', 'iatacode': 'ALG', 'country': 'DZ'}
# - name - {} - Houari Boumediene
# - latitude - {} - 36.691014
# - longitude - {} - 3.215408
# - elevation - {} - 25
# - gmtOffset - {} - 1
# airport {'city': 'cty-Algeria-13', 'iatacode': 'TLM', 'country': 'DZ'}
# - name - {} - Zenata
# - latitude - {} - 35.016667
# - longitude - {} - -1.45
# - elevation - {} - 248
# - gmtOffset - {} - 1
# airport {'city': 'city-Pago-Pago-AMSA-AMSA', 'iatacode': 'PPG', 'country': 'AMSA'}
# - name - {} - Pago Pago Intl
# - latitude - {} - -14.2794
# - longitude - {} - 170.7006
# - elevation - {} - 10
# - gmtOffset - {} - 11
# - located_on - {'island': 'island-Tutuila'} - None
# airport {'city': 'cty-Angola-Lubango', 'iatacode': 'SDD', 'country': 'ANG'}
# - name - {} - Lubango
# - latitude - {} - -14.924733
# - longitude - {} - 13.575022
# - elevation - {} - 1762
# - gmtOffset - {} - 1
# airport {'city': 'cty-Angola-Cabinda', 'iatacode': 'CAB', 'country': 'ANG'}
# - name - {} - Cabinda
# - latitude - {} - -5.596992
# - longitude - {} - 12.188353
# - elevation - {} - 20
# - gmtOffset - {} - 1
# airport {'city': 'cty-Angola-Menongue', 'iatacode': 'SPP', 'country': 'ANG'}
# - name - {} - Menongue
# - latitude - {} - -14.657583
# - longitude - {} - 17.719833
# - elevation - {} - 1363
# - gmtOffset - {} - 1
# airport {'city': 'cty-Angola-Luanda', 'iatacode': 'LAD', 'country': 'ANG'}
# - name - {} - Luanda 4 De Fevereiro
# - latitude - {} - -8.858375
# - longitude - {} - 13.231178
# - elevation - {} - 74
# - gmtOffset - {} - 1
# airport {'city': 'cty-Angola-Huambo', 'iatacode': 'NOV', 'country': 'ANG'}
# - name - {} - Huambo
# - latitude - {} - -12.808878
# - longitude - {} - 15.760547
# - elevation - {} - 1703
# - gmtOffset - {} - 1
# airport {'city': 'city-The-Valley-AXA-AXA', 'iatacode': 'AXA', 'country': 'AXA'}
# - name - {} - Wallblake
# - latitude - {} - 18.204834
# - longitude - {} - -63.055084
# - elevation - {} - 39
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-Anguilla'} - None
# airport {'city': 'cty-Antigua-and-Barbuda-Saint-Johns', 'iatacode': 'ANU', 'country': 'AG'}
# - name - {} - V C Bird Intl
# - latitude - {} - 17.136749
# - longitude - {} - -61.792667
# - elevation - {} - 19
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-Antigua'} - None
# airport {'city': 'cty-Argentina-37', 'iatacode': 'IRJ', 'country': 'RA'}
# - name - {} - La Rioja
# - latitude - {} - -29.381636
# - longitude - {} - -66.795839
# - elevation - {} - 438
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-28', 'iatacode': 'JUJ', 'country': 'RA'}
# - name - {} - Jujuy
# - latitude - {} - -24.392778
# - longitude - {} - -65.097778
# - elevation - {} - 920
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-23', 'iatacode': 'BHI', 'country': 'RA'}
# - name - {} - Comandante Espora
# - latitude - {} - -38.724967
# - longitude - {} - -62.169317
# - elevation - {} - 75
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-9', 'iatacode': 'TUC', 'country': 'RA'}
# - name - {} - Teniente Benjamin Matienzo
# - latitude - {} - -26.840861
# - longitude - {} - -65.104944
# - elevation - {} - 456
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-36', 'iatacode': 'LUQ', 'country': 'RA'}
# - name - {} - San Luis
# - latitude - {} - -33.273192
# - longitude - {} - -66.356422
# - elevation - {} - 710
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-22', 'iatacode': 'SDE', 'country': 'RA'}
# - name - {} - Santiago del Estero
# - latitude - {} - -27.765617
# - longitude - {} - -64.310122
# - elevation - {} - 200
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-15', 'iatacode': 'SFN', 'country': 'RA'}
# - name - {} - Sauce Viejo
# - latitude - {} - -31.711666
# - longitude - {} - -60.811668
# - elevation - {} - 17
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-24', 'iatacode': 'CNQ', 'country': 'RA'}
# - name - {} - Corrientes
# - latitude - {} - -27.445503
# - longitude - {} - -58.761864
# - elevation - {} - 62
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-25', 'iatacode': 'NQN', 'country': 'RA'}
# - name - {} - Presidente Peron
# - latitude - {} - -38.949
# - longitude - {} - -68.155711
# - elevation - {} - 273
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-16', 'iatacode': 'SLA', 'country': 'RA'}
# - name - {} - Salta
# - latitude - {} - -24.855978
# - longitude - {} - -65.486169
# - elevation - {} - 1246
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-Buenos-Aires', 'iatacode': 'AEP', 'country': 'RA'}
# - name - {} - Aeroparque Jorge Newbery
# - latitude - {} - -34.559175
# - longitude - {} - -58.415606
# - elevation - {} - 5
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-Buenos-Aires', 'iatacode': 'EZE', 'country': 'RA'}
# - name - {} - Ministro Pistarini
# - latitude - {} - -34.822222
# - longitude - {} - -58.535833
# - elevation - {} - 20
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-Ushuaia', 'iatacode': 'USH', 'country': 'RA'}
# - name - {} - Ushuaia Malvinas Argentinas
# - latitude - {} - -54.843278
# - longitude - {} - -68.29575
# - elevation - {} - 22
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-29', 'iatacode': 'FMA', 'country': 'RA'}
# - name - {} - Formosa
# - latitude - {} - -26.212722
# - longitude - {} - -58.228111
# - elevation - {} - 59
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-27', 'iatacode': 'PSS', 'country': 'RA'}
# - name - {} - Posadas
# - latitude - {} - -27.385839
# - longitude - {} - -55.970728
# - elevation - {} - 131
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-4', 'iatacode': 'ROS', 'country': 'RA'}
# - name - {} - Rosario
# - latitude - {} - -32.903611
# - longitude - {} - -60.785
# - elevation - {} - 26
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-20', 'iatacode': 'RES', 'country': 'RA'}
# - name - {} - Resistencia
# - latitude - {} - -27.449986
# - longitude - {} - -59.056125
# - elevation - {} - 53
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-Rio-Gallegos', 'iatacode': 'RGL', 'country': 'RA'}
# - name - {} - Rio Gallegos
# - latitude - {} - -51.608875
# - longitude - {} - -69.312636
# - elevation - {} - 19
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-32', 'iatacode': 'CRD', 'country': 'RA'}
# - name - {} - Comodoro Rivadavia
# - latitude - {} - -45.785347
# - longitude - {} - -67.465508
# - elevation - {} - 58
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-11', 'iatacode': 'MDQ', 'country': 'RA'}
# - name - {} - Mar Del Plata
# - latitude - {} - -37.934167
# - longitude - {} - -57.573333
# - elevation - {} - 22
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-6', 'iatacode': 'MDZ', 'country': 'RA'}
# - name - {} - El Plumerillo
# - latitude - {} - -32.831717
# - longitude - {} - -68.792856
# - elevation - {} - 704
# - gmtOffset - {} - -3
# airport {'city': 'cty-Argentina-Cordoba', 'iatacode': 'COR', 'country': 'RA'}
# - name - {} - Ambrosio L V Taravella
# - latitude - {} - -31.323619
# - longitude - {} - -64.207953
# - elevation - {} - 489
# - gmtOffset - {} - -3
# airport {'city': 'cty-Armenia-Yerevan', 'iatacode': 'EVN', 'country': 'ARM'}
# - name - {} - Zvartnots
# - latitude - {} - 40.147275
# - longitude - {} - 44.395881
# - elevation - {} - 865
# - gmtOffset - {} - 4
# airport {'city': 'city-Oranjestad-ARU-ARU', 'iatacode': 'AUA', 'country': 'ARU'}
# - name - {} - Reina Beatrix Intl
# - latitude - {} - 12.501389
# - longitude - {} - -70.015221
# - elevation - {} - 18
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-Aruba'} - None
# airport {'city': 'cty-Australia-Melbourne', 'iatacode': 'MEL', 'country': 'AUS'}
# - name - {} - Melbourne Intl
# - latitude - {} - -37.673333
# - longitude - {} - 144.843333
# - elevation - {} - 132
# - gmtOffset - {} - 10
# airport {'city': 'cty-Australia-Sydney', 'iatacode': 'SYD', 'country': 'AUS'}
# - name - {} - Sydney Intl
# - latitude - {} - -33.946111
# - longitude - {} - 151.177222
# - elevation - {} - 6
# - gmtOffset - {} - 10
# airport {'city': 'cty-Australia-Cairns', 'iatacode': 'CNS', 'country': 'AUS'}
# - name - {} - Cairns Intl
# - latitude - {} - -16.885833
# - longitude - {} - 145.755278
# - elevation - {} - 3
# - gmtOffset - {} - 10
# airport {'city': 'cty-Australia-13', 'iatacode': 'TSV', 'country': 'AUS'}
# - name - {} - Townsville
# - latitude - {} - -19.2525
# - longitude - {} - 146.765278
# - elevation - {} - 5
# - gmtOffset - {} - 10
# airport {'city': 'cty-Australia-Brisbane', 'iatacode': 'BNE', 'country': 'AUS'}
# - name - {} - Brisbane Intl
# - latitude - {} - -27.384167
# - longitude - {} - 153.1175
# - elevation - {} - 4
# - gmtOffset - {} - 10
# airport {'city': 'cty-Australia-8', 'iatacode': 'CBR', 'country': 'AUS'}
# - name - {} - Canberra
# - latitude - {} - -35.306944
# - longitude - {} - 149.195
# - elevation - {} - 575
# - gmtOffset - {} - 10
# airport {'city': 'cty-Australia-Adelaide', 'iatacode': 'ADL', 'country': 'AUS'}
# - name - {} - Adelaide Intl
# - latitude - {} - -34.945
# - longitude - {} - 138.530556
# - elevation - {} - 6
# - gmtOffset - {} - 9.5
# airport {'city': 'cty-Australia-7', 'iatacode': 'NTL', 'country': 'AUS'}
# - name - {} - Newcastle Airport
# - latitude - {} - -32.78
# - longitude - {} - 151.83
# - elevation - {} - 9
# - gmtOffset - {} - 10
# airport {'city': 'cty-Australia-Darwin', 'iatacode': 'DRW', 'country': 'AUS'}
# - name - {} - Darwin Intl
# - latitude - {} - -12.4083333
# - longitude - {} - 130.87266
# - elevation - {} - 31
# - gmtOffset - {} - 9.5
# airport {'city': 'cty-Australia-Perth', 'iatacode': 'PER', 'country': 'AUS'}
# - name - {} - Perth Intl
# - latitude - {} - -31.940278
# - longitude - {} - 115.966944
# - elevation - {} - 20
# - gmtOffset - {} - 8
# airport {'city': 'cty-Australia-11', 'iatacode': 'HBA', 'country': 'AUS'}
# - name - {} - Hobart
# - latitude - {} - -42.836111
# - longitude - {} - 147.510278
# - elevation - {} - 4
# - gmtOffset - {} - 10
# - located_on - {'island': 'island-Tasmania'} - None
# airport {'city': 'cty-Austria-5', 'iatacode': 'SZG', 'country': 'A'}
# - name - {} - Salzburg
# - latitude - {} - 47.793304
# - longitude - {} - 13.004333
# - elevation - {} - 430
# - gmtOffset - {} - 1
# airport {'city': 'cty-Austria-4', 'iatacode': 'LNZ', 'country': 'A'}
# - name - {} - Linz
# - latitude - {} - 48.233219
# - longitude - {} - 14.187511
# - elevation - {} - 298
# - gmtOffset - {} - 1
# airport {'city': 'cty-Austria-6', 'iatacode': 'INN', 'country': 'A'}
# - name - {} - Innsbruck
# - latitude - {} - 47.260219
# - longitude - {} - 11.343964
# - elevation - {} - 581
# - gmtOffset - {} - 1
# airport {'city': 'cty-Austria-Vienna', 'iatacode': 'VIE', 'country': 'A'}
# - name - {} - Schwechat
# - latitude - {} - 48.110278
# - longitude - {} - 16.569722
# - elevation - {} - 183
# - gmtOffset - {} - 1
# airport {'city': 'cty-Austria-3', 'iatacode': 'GRZ', 'country': 'A'}
# - name - {} - Graz
# - latitude - {} - 46.991067
# - longitude - {} - 15.439628
# - elevation - {} - 340
# - gmtOffset - {} - 1
# airport {'city': 'cty-Austria-Klagenfurt', 'iatacode': 'KLU', 'country': 'A'}
# - name - {} - Woerthersee International Airport
# - latitude - {} - 46.642514
# - longitude - {} - 14.337739
# - elevation - {} - 138
# - gmtOffset - {} - 1
# airport {'city': 'cty-Azerbaijan-Baku', 'iatacode': 'GYD', 'country': 'AZ'}
# - name - {} - Heydar Aliyev
# - latitude - {} - 40.4675
# - longitude - {} - 50.046667
# - elevation - {} - 3
# - gmtOffset - {} - 4
# airport {'city': 'cty-Bahamas-Nassau', 'iatacode': 'NAS', 'country': 'BS'}
# - name - {} - Lynden Pindling Intl
# - latitude - {} - 25.038958
# - longitude - {} - -77.466231
# - elevation - {} - 5
# - gmtOffset - {} - -5
# - located_on - {'island': 'island-NewProvidence'} - None
# airport {'city': 'cty-Bahrain-Manama', 'iatacode': 'BAH', 'country': 'BRN'}
# - name - {} - Bahrain Intl
# - latitude - {} - 26.270834
# - longitude - {} - 50.63361
# - elevation - {} - 2
# - gmtOffset - {} - 3
# - located_on - {'island': 'island-Bahrain'} - None
# airport {'city': 'cty-BD-3', 'iatacode': 'DAC', 'country': 'BD'}
# - name - {} - Zia Intl
# - latitude - {} - 23.843333
# - longitude - {} - 90.397781
# - elevation - {} - 9
# - gmtOffset - {} - 6
# airport {'city': 'cty-BD-2', 'iatacode': 'CGP', 'country': 'BD'}
# - name - {} - Shah Amanat Intl
# - latitude - {} - 22.249611
# - longitude - {} - 91.813286
# - elevation - {} - 4
# - gmtOffset - {} - 6
# airport {'city': 'cty-Barbados-Bridgetown', 'iatacode': 'BGI', 'country': 'BDS'}
# - name - {} - Grantley Adams Intl
# - latitude - {} - 13.074603
# - longitude - {} - -59.492456
# - elevation - {} - 52
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-Barbados'} - None
# airport {'city': 'cty-Belarus-Minsk', 'iatacode': 'MSQ', 'country': 'BY'}
# - name - {} - Minsk 2
# - latitude - {} - 53.882469
# - longitude - {} - 28.030731
# - elevation - {} - 204
# - gmtOffset - {} - 2
# airport {'city': 'cty-Belgium-3-0', 'iatacode': 'ANR', 'country': 'B'}
# - name - {} - Deurne
# - latitude - {} - 51.189444
# - longitude - {} - 4.460278
# - elevation - {} - 12
# - gmtOffset - {} - 1
# airport {'city': 'cty-Belgium-5-0', 'iatacode': 'CRL', 'country': 'B'}
# - name - {} - Brussels South
# - latitude - {} - 50.459197
# - longitude - {} - 4.453817
# - elevation - {} - 187
# - gmtOffset - {} - 1
# airport {'city': 'cty-Belgium-6-0', 'iatacode': 'LGG', 'country': 'B'}
# - name - {} - Aéroport de Liège
# - latitude - {} - 50.6375
# - longitude - {} - 5.4433
# - elevation - {} - 201
# - gmtOffset - {} - 1
# airport {'city': 'cty-Belgium-Brussels', 'iatacode': 'BRU', 'country': 'B'}
# - name - {} - Brussels Natl
# - latitude - {} - 50.901389
# - longitude - {} - 4.484444
# - elevation - {} - 56
# - gmtOffset - {} - 1
# airport {'city': 'cty-Belize-Belize', 'iatacode': 'BZE', 'country': 'BZ'}
# - name - {} - Philip S W Goldson Intl
# - latitude - {} - 17.539144
# - longitude - {} - -88.308203
# - elevation - {} - 5
# - gmtOffset - {} - -6
# airport {'city': 'cty-Benin-Cotonou', 'iatacode': 'COO', 'country': 'BEN'}
# - name - {} - Cadjehoun
# - latitude - {} - 6.357228
# - longitude - {} - 2.384353
# - elevation - {} - 6
# - gmtOffset - {} - 1
# airport {'city': 'city-Hamilton-BERM-BERM', 'iatacode': 'BDA', 'country': 'BERM'}
# - name - {} - Bermuda Intl
# - latitude - {} - 32.364042
# - longitude - {} - -64.678703
# - elevation - {} - 4
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-GrandBermuda'} - None
# airport {'city': 'cty-Bhutan-Thimphu', 'iatacode': 'PBH', 'country': 'BHT'}
# - name - {} - Paro
# - latitude - {} - 27.403192
# - longitude - {} - 89.424606
# - elevation - {} - 2235
# - gmtOffset - {} - 6
# airport {'city': 'cty-BOL-6', 'iatacode': 'CIJ', 'country': 'BOL'}
# - name - {} - Heroes Del Acre
# - latitude - {} - -11.040436
# - longitude - {} - -68.782972
# - elevation - {} - 272
# - gmtOffset - {} - -4
# airport {'city': 'cty-BOL-1', 'iatacode': 'LPB', 'country': 'BOL'}
# - name - {} - El Alto Intl
# - latitude - {} - -16.513339
# - longitude - {} - -68.192256
# - elevation - {} - 4063
# - gmtOffset - {} - -4
# airport {'city': 'cty-BOL-4', 'iatacode': 'VVI', 'country': 'BOL'}
# - name - {} - Viru Viru Intl
# - latitude - {} - -17.644756
# - longitude - {} - -63.135364
# - elevation - {} - 373
# - gmtOffset - {} - -4
# airport {'city': 'cty-BOL-7', 'iatacode': 'SRE', 'country': 'BOL'}
# - name - {} - Juana Azurduy De Padilla
# - latitude - {} - -19.007083
# - longitude - {} - -65.288747
# - elevation - {} - 2905
# - gmtOffset - {} - -4
# airport {'city': 'cty-BOL-5', 'iatacode': 'TDD', 'country': 'BOL'}
# - name - {} - Tte Av Jorge Henrich Arauz
# - latitude - {} - -14.818739
# - longitude - {} - -64.918019
# - elevation - {} - 155
# - gmtOffset - {} - -4
# airport {'city': 'cty-BOL-9', 'iatacode': 'TJA', 'country': 'BOL'}
# - name - {} - Capitan Oriel Lea Plaza
# - latitude - {} - -21.555736
# - longitude - {} - -64.701325
# - elevation - {} - 1855
# - gmtOffset - {} - -4
# airport {'city': 'cty-BOL-8', 'iatacode': 'CBB', 'country': 'BOL'}
# - name - {} - Jorge Wilsterman
# - latitude - {} - -17.421058
# - longitude - {} - -66.177114
# - elevation - {} - 2549
# - gmtOffset - {} - -4
# airport {'city': 'cty-BIH-1', 'iatacode': 'SJJ', 'country': 'BIH'}
# - name - {} - Sarajevo
# - latitude - {} - 43.824583
# - longitude - {} - 18.331467
# - elevation - {} - 521
# - gmtOffset - {} - 1
# airport {'city': 'cty-Botswana-Gaborone', 'iatacode': 'GBE', 'country': 'RB'}
# - name - {} - Sir Seretse Khama Intl
# - latitude - {} - -24.555225
# - longitude - {} - 25.918208
# - elevation - {} - 1006
# - gmtOffset - {} - 2
# airport {'city': 'cty-Brazil-Recife', 'iatacode': 'REC', 'country': 'BR'}
# - name - {} - Guararapes Gilberto Freyre Intl
# - latitude - {} - -8.126794
# - longitude - {} - -34.923039
# - elevation - {} - 10
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Brasilia', 'iatacode': 'BSB', 'country': 'BR'}
# - name - {} - Presidente Juscelino Kubitschek
# - latitude - {} - -15.8711
# - longitude - {} - -47.918625
# - elevation - {} - 1061
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-134', 'iatacode': 'BVB', 'country': 'BR'}
# - name - {} - Boa Vista
# - latitude - {} - 2.846311
# - longitude - {} - -60.690069
# - elevation - {} - 84
# - gmtOffset - {} - -4
# airport {'city': 'cty-Brazil-34', 'iatacode': 'UDI', 'country': 'BR'}
# - name - {} - Ten Cel Av Cesar Bombonato
# - latitude - {} - -18.882844
# - longitude - {} - -48.225594
# - elevation - {} - 943
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-19', 'iatacode': 'MCZ', 'country': 'BR'}
# - name - {} - Zumbi Dos Palmares
# - latitude - {} - -9.510808
# - longitude - {} - -35.791678
# - elevation - {} - 118
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-93', 'iatacode': 'MCP', 'country': 'BR'}
# - name - {} - Macapa
# - latitude - {} - .050664
# - longitude - {} - -51.072178
# - elevation - {} - 17
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-12', 'iatacode': 'MAO', 'country': 'BR'}
# - name - {} - Eduardo Gomes Intl
# - latitude - {} - -3.038611
# - longitude - {} - -60.049721
# - elevation - {} - 80
# - gmtOffset - {} - -4
# airport {'city': 'cty-Brazil-71', 'iatacode': 'VIX', 'country': 'BR'}
# - name - {} - Goiabeiras
# - latitude - {} - -20.258056
# - longitude - {} - -40.286389
# - elevation - {} - 3
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Curitiba', 'iatacode': 'CWB', 'country': 'BR'}
# - name - {} - Afonso Pena
# - latitude - {} - -25.528475
# - longitude - {} - -49.175775
# - elevation - {} - 911
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-74', 'iatacode': 'STM', 'country': 'BR'}
# - name - {} - Santarem
# - latitude - {} - -2.422431
# - longitude - {} - -54.792789
# - elevation - {} - 60
# - gmtOffset - {} - -4
# airport {'city': 'cty-Brazil-40', 'iatacode': 'LDB', 'country': 'BR'}
# - name - {} - Londrina
# - latitude - {} - -23.333625
# - longitude - {} - -51.130072
# - elevation - {} - 569
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-36', 'iatacode': 'CGB', 'country': 'BR'}
# - name - {} - Marechal Rondon
# - latitude - {} - -15.652931
# - longitude - {} - -56.116719
# - elevation - {} - 188
# - gmtOffset - {} - -4
# airport {'city': 'cty-Brazil-26', 'iatacode': 'CGR', 'country': 'BR'}
# - name - {} - Campo Grande
# - latitude - {} - -20.468667
# - longitude - {} - -54.6725
# - elevation - {} - 559
# - gmtOffset - {} - -4
# airport {'city': 'cty-Brazil-Sao-Paulo', 'iatacode': 'CGH', 'country': 'BR'}
# - name - {} - Congonhas
# - latitude - {} - -23.626692
# - longitude - {} - -46.655375
# - elevation - {} - 802
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-3', 'iatacode': 'SDU', 'country': 'BR'}
# - name - {} - Santos Dumont
# - latitude - {} - -22.910461
# - longitude - {} - -43.163133
# - elevation - {} - 3
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Salvador', 'iatacode': 'SSA', 'country': 'BR'}
# - name - {} - Deputado Luis Eduardo Magalhaes
# - latitude - {} - -12.910994
# - longitude - {} - -38.331044
# - elevation - {} - 20
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Belo-Horizonte', 'iatacode': 'CNF', 'country': 'BR'}
# - name - {} - Tancredo Neves Intl
# - latitude - {} - -19.63375
# - longitude - {} - -43.968856
# - elevation - {} - 828
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-18', 'iatacode': 'SLZ', 'country': 'BR'}
# - name - {} - Marechal Cunha Machado Intl
# - latitude - {} - -2.585361
# - longitude - {} - -44.234139
# - elevation - {} - 54
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-15', 'iatacode': 'CPQ', 'country': 'BR'}
# - name - {} - Amarais Airport
# - latitude - {} - -22.8592
# - longitude - {} - -47.1082
# - elevation - {} - 612
# - gmtOffset - {} - -4
# airport {'city': 'cty-Brazil-15', 'iatacode': 'VCP', 'country': 'BR'}
# - name - {} - Viracopos
# - latitude - {} - -23.0075
# - longitude - {} - -47.134444
# - elevation - {} - 662
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-38', 'iatacode': 'AJU', 'country': 'BR'}
# - name - {} - Santa Maria
# - latitude - {} - -10.984
# - longitude - {} - -37.070333
# - elevation - {} - 7
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-78', 'iatacode': 'UBA', 'country': 'BR'}
# - name - {} - Uberaba
# - latitude - {} - -19.765
# - longitude - {} - -47.964778
# - elevation - {} - 809
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Belem', 'iatacode': 'BEL', 'country': 'BR'}
# - name - {} - Val De Cans Intl
# - latitude - {} - -1.37925
# - longitude - {} - -48.476292
# - elevation - {} - 16
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-23', 'iatacode': 'THE', 'country': 'BR'}
# - name - {} - Senador Petronio Portella
# - latitude - {} - -5.059942
# - longitude - {} - -42.823478
# - elevation - {} - 67
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-22', 'iatacode': 'NAT', 'country': 'BR'}
# - name - {} - Augusto Severo
# - latitude - {} - -5.911417
# - longitude - {} - -35.247717
# - elevation - {} - 52
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-54', 'iatacode': 'PET', 'country': 'BR'}
# - name - {} - Pelotas
# - latitude - {} - -31.718353
# - longitude - {} - -52.327689
# - elevation - {} - 18
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-31', 'iatacode': 'RAO', 'country': 'BR'}
# - name - {} - Leite Lopes
# - latitude - {} - -21.134167
# - longitude - {} - -47.774189
# - elevation - {} - 549
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-203', 'iatacode': 'RVD', 'country': 'BR'}
# - name - {} - General Leite de Castro Airport
# - latitude - {} - -17.790278
# - longitude - {} - -50.918333
# - elevation - {} - 684
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-81', 'iatacode': 'GVR', 'country': 'BR'}
# - name - {} - Governador Valadares Airport
# - latitude - {} - -18.8952
# - longitude - {} - -41.9822
# - elevation - {} - 171
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-99', 'iatacode': 'IPN', 'country': 'BR'}
# - name - {} - Usiminas
# - latitude - {} - -19.470722
# - longitude - {} - -42.487583
# - elevation - {} - 239
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-50', 'iatacode': 'CXJ', 'country': 'BR'}
# - name - {} - Campo Dos Bugres
# - latitude - {} - -29.197064
# - longitude - {} - -51.187536
# - elevation - {} - 754
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-3', 'iatacode': 'GIG', 'country': 'BR'}
# - name - {} - Galeao Antonio Carlos Jobim
# - latitude - {} - -22.808903
# - longitude - {} - -43.243647
# - elevation - {} - 9
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Fortaleza', 'iatacode': 'FOR', 'country': 'BR'}
# - name - {} - Pinto Martins Intl
# - latitude - {} - -3.776283
# - longitude - {} - -38.532556
# - elevation - {} - 25
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Belo-Horizonte', 'iatacode': 'PLU', 'country': 'BR'}
# - name - {} - Pampulha Carlos Drummond De Andrade
# - latitude - {} - -19.851181
# - longitude - {} - -43.950628
# - elevation - {} - 789
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-58', 'iatacode': 'PVH', 'country': 'BR'}
# - name - {} - Governador Jorge Teixeira De Oliveira
# - latitude - {} - -8.709294
# - longitude - {} - -63.902281
# - elevation - {} - 90
# - gmtOffset - {} - -4
# airport {'city': 'cty-Brazil-13', 'iatacode': 'GYN', 'country': 'BR'}
# - name - {} - Santa Genoveva
# - latitude - {} - -16.632033
# - longitude - {} - -49.220686
# - elevation - {} - 747
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Porto-Alegre', 'iatacode': 'POA', 'country': 'BR'}
# - name - {} - Salgado Filho
# - latitude - {} - -29.994428
# - longitude - {} - -51.171428
# - elevation - {} - 3
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-Sao-Paulo', 'iatacode': 'GRU', 'country': 'BR'}
# - name - {} - Guarulhos Gov Andre Franco Montouro
# - latitude - {} - -23.432075
# - longitude - {} - -46.469511
# - elevation - {} - 750
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-87', 'iatacode': 'IMP', 'country': 'BR'}
# - name - {} - Prefeito Renato Moreira
# - latitude - {} - -5.531292
# - longitude - {} - -47.46005
# - elevation - {} - 131
# - gmtOffset - {} - -3
# airport {'city': 'cty-Brazil-75', 'iatacode': 'IOS', 'country': 'BR'}
# - name - {} - Ilheus
# - latitude - {} - -14.815964
# - longitude - {} - -39.033197
# - elevation - {} - 5
# - gmtOffset - {} - -3
# airport {'city': 'city-Road-Town-BVIR-BVIR', 'iatacode': 'EIS', 'country': 'BVIR'}
# - name - {} - Terrance B Lettsome Intl
# - latitude - {} - 18.444834
# - longitude - {} - -64.542975
# - elevation - {} - 5
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-Tortola'} - None
# airport {'city': 'cty-Brunei-Bandar-Seri-Begawan', 'iatacode': 'BWN', 'country': 'BRU'}
# - name - {} - Brunei Intl
# - latitude - {} - 4.9442
# - longitude - {} - 114.928353
# - elevation - {} - 22
# - gmtOffset - {} - 8
# - located_on - {'island': 'island-Borneo'} - None
# airport {'city': 'cty-Bulgaria-4', 'iatacode': 'BOJ', 'country': 'BG'}
# - name - {} - Burgas
# - latitude - {} - 42.569583
# - longitude - {} - 27.515236
# - elevation - {} - 41
# - gmtOffset - {} - 2
# airport {'city': 'cty-Bulgaria-3', 'iatacode': 'VAR', 'country': 'BG'}
# - name - {} - Varna
# - latitude - {} - 43.232072
# - longitude - {} - 27.825106
# - elevation - {} - 70
# - gmtOffset - {} - 2
# airport {'city': 'cty-Bulgaria-2', 'iatacode': 'PDV', 'country': 'BG'}
# - name - {} - Plovdiv
# - latitude - {} - 42.067806
# - longitude - {} - 24.850833
# - elevation - {} - 182
# - gmtOffset - {} - 2
# airport {'city': 'cty-Bulgaria-1', 'iatacode': 'SOF', 'country': 'BG'}
# - name - {} - Sofia
# - latitude - {} - 42.695194
# - longitude - {} - 23.406167
# - elevation - {} - 531
# - gmtOffset - {} - 2
# airport {'city': 'cty-Burkina-BoboDioulasso', 'iatacode': 'BOY', 'country': 'BF'}
# - name - {} - Bobo Dioulasso
# - latitude - {} - 11.160056
# - longitude - {} - -4.330969
# - elevation - {} - 461
# - gmtOffset - {} - 0
# airport {'city': 'cty-Burkina-Faso-Ouagadougou', 'iatacode': 'OUA', 'country': 'BF'}
# - name - {} - Ouagadougou
# - latitude - {} -  12.353194
# - longitude - {} - -1.512417
# - elevation - {} - 316
# - gmtOffset - {} - 0
# airport {'city': 'cty-Burma-Mandalay', 'iatacode': 'MDL', 'country': 'MYA'}
# - name - {} - Mandalay Intl
# - latitude - {} - 21.702156
# - longitude - {} - 95.977928
# - elevation - {} - 91
# - gmtOffset - {} - 6.5
# airport {'city': 'cty-Burma-Rangoon', 'iatacode': 'RGN', 'country': 'MYA'}
# - name - {} - Yangon Intl
# - latitude - {} - 16.907305
# - longitude - {} - 96.133222
# - elevation - {} - 33
# - gmtOffset - {} - 6.5
# airport {'city': 'cty-Burundi-Bujumbura', 'iatacode': 'BJM', 'country': 'BI'}
# - name - {} - Bujumbura Intl
# - latitude - {} - -3.324019
# - longitude - {} - 29.318519
# - elevation - {} - 787
# - gmtOffset - {} - 2
# airport {'city': 'cty-Cambodia-Phnom-Penh', 'iatacode': 'PNH', 'country': 'K'}
# - name - {} - Phnom Penh Intl
# - latitude - {} - 11.546556
# - longitude - {} - 104.844139
# - elevation - {} - 12
# - gmtOffset - {} - 7
# airport {'city': 'cty-Cameroon-2', 'iatacode': 'DLA', 'country': 'CAM'}
# - name - {} - Douala
# - latitude - {} - 4.006081
# - longitude - {} - 9.719481
# - elevation - {} - 10
# - gmtOffset - {} - 1
# airport {'city': 'cty-Cameroon-3', 'iatacode': 'NSI', 'country': 'CAM'}
# - name - {} - Yaounde Nsimalen
# - latitude - {} - 3.722556
# - longitude - {} - 11.553269
# - elevation - {} - 695
# - gmtOffset - {} - 1
# airport {'city': 'cty-Canada-Gander', 'iatacode': 'YQX', 'country': 'CDN'}
# - name - {} - Gander Intl
# - latitude - {} - 48.936944
# - longitude - {} - -54.568056
# - elevation - {} - 151
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-Newfoundland'} - None
# airport {'city': 'cty-Canada-Whitehorse', 'iatacode': 'YXY', 'country': 'CDN'}
# - name - {} - Whitehorse Intl
# - latitude - {} - 60.709553
# - longitude - {} - -135.067269
# - elevation - {} - 706
# - gmtOffset - {} - -8
# airport {'city': 'cty-Canada-Iqaluit', 'iatacode': 'YFB', 'country': 'CDN'}
# - name - {} - Iqaluit
# - latitude - {} - 63.75639
# - longitude - {} - -68.555832
# - elevation - {} - 34
# - gmtOffset - {} - -5
# - located_on - {'island': 'island-Baffin_Island'} - None
# airport {'city': 'cty-Canada-Saint-Johns', 'iatacode': 'YYT', 'country': 'CDN'}
# - name - {} - St Johns Intl
# - latitude - {} - 47.61861
# - longitude - {} - -52.751945
# - elevation - {} - 141
# - gmtOffset - {} - -3.5
# - located_on - {'island': 'island-Newfoundland'} - None
# airport {'city': 'cty-Canada-4', 'iatacode': 'YYZ', 'country': 'CDN'}
# - name - {} - Lester B Pearson Intl
# - latitude - {} - 43.677223
# - longitude - {} - -79.630556
# - elevation - {} - 173
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-3', 'iatacode': 'YYC', 'country': 'CDN'}
# - name - {} - Calgary Intl
# - latitude - {} - 51.113888
# - longitude - {} - -114.020278
# - elevation - {} - 1084
# - gmtOffset - {} - -7
# airport {'city': 'cty-Canada-Victoria', 'iatacode': 'YYJ', 'country': 'CDN'}
# - name - {} - Victoria Intl
# - latitude - {} - 48.646944
# - longitude - {} - -123.425833
# - elevation - {} - 19
# - gmtOffset - {} - -8
# - located_on - {'island': 'island-Vancouver_Island'} - None
# airport {'city': 'cty-Canada-15', 'iatacode': 'YXU', 'country': 'CDN'}
# - name - {} - London
# - latitude - {} - 43.033056
# - longitude - {} - -81.151111
# - elevation - {} - 278
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-19', 'iatacode': 'YXE', 'country': 'CDN'}
# - name - {} - Saskatoon J G Diefenbaker Intl
# - latitude - {} - 52.170834
# - longitude - {} - -106.699722
# - elevation - {} - 504
# - gmtOffset - {} - -6
# airport {'city': 'cty-Canada-Yellowknife', 'iatacode': 'YZF', 'country': 'CDN'}
# - name - {} - Yellowknife
# - latitude - {} - 62.462778
# - longitude - {} - -114.440278
# - elevation - {} - 206
# - gmtOffset - {} - -7
# airport {'city': 'cty-Canada-22', 'iatacode': 'YQB', 'country': 'CDN'}
# - name - {} - Quebec Jean Lesage Intl
# - latitude - {} - 46.791111
# - longitude - {} - -71.393333
# - elevation - {} - 74
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-32', 'iatacode': 'YQT', 'country': 'CDN'}
# - name - {} - Thunder Bay
# - latitude - {} - 48.371944
# - longitude - {} - -89.323889
# - elevation - {} - 199
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-20', 'iatacode': 'YQR', 'country': 'CDN'}
# - name - {} - Regina Intl
# - latitude - {} - 50.431944
# - longitude - {} - -104.665833
# - elevation - {} - 577
# - gmtOffset - {} - -6
# airport {'city': 'cty-Canada-13', 'iatacode': 'YOW', 'country': 'CDN'}
# - name - {} - Ottawa Macdonald Cartier Intl
# - latitude - {} - 45.3225
# - longitude - {} - -75.669167
# - elevation - {} - 114
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-2', 'iatacode': 'YUL', 'country': 'CDN'}
# - name - {} - Pierre Elliott Trudeau Intl
# - latitude - {} - 45.470556
# - longitude - {} - -73.740833
# - elevation - {} - 36
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-4', 'iatacode': 'YTZ', 'country': 'CDN'}
# - name - {} - City Centre
# - latitude - {} - 43.627499
# - longitude - {} - -79.396167
# - elevation - {} - 77
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-5', 'iatacode': 'YWG', 'country': 'CDN'}
# - name - {} - Winnipeg Intl
# - latitude - {} - 49.910036
# - longitude - {} - -97.239886
# - elevation - {} - 239
# - gmtOffset - {} - -6
# airport {'city': 'cty-Canada-9', 'iatacode': 'YVR', 'country': 'CDN'}
# - name - {} - Vancouver Intl
# - latitude - {} - 49.193889
# - longitude - {} - -123.184444
# - elevation - {} - 4
# - gmtOffset - {} - -8
# airport {'city': 'cty-Canada-11', 'iatacode': 'YHM', 'country': 'CDN'}
# - name - {} - Hamilton
# - latitude - {} - 43.173611
# - longitude - {} - -79.935
# - elevation - {} - 238
# - gmtOffset - {} - -5
# airport {'city': 'cty-Canada-31', 'iatacode': 'YHZ', 'country': 'CDN'}
# - name - {} - Halifax Intl
# - latitude - {} - 44.880833
# - longitude - {} - -63.50861
# - elevation - {} - 145
# - gmtOffset - {} - -4
# airport {'city': 'cty-Canada-6', 'iatacode': 'YEG', 'country': 'CDN'}
# - name - {} - Edmonton Intl
# - latitude - {} - 53.309723
# - longitude - {} - -113.579722
# - elevation - {} - 723
# - gmtOffset - {} - -7
# airport {'city': 'cty-Cape-Verde-Praia', 'iatacode': 'RAI', 'country': 'CV'}
# - name - {} - Praia International Airport
# - latitude - {} - 14.9245
# - longitude - {} - -23.4935
# - elevation - {} - 70
# - gmtOffset - {} - -1
# - located_on - {'island': 'island-Santiago'} - None
# airport {'country': 'CAYM', 'iatacode': 'LYB'}
# - name - {} - Edward Bodden Airfield
# - latitude - {} - 19.6591666667
# - longitude - {} - -80.09083333
# - elevation - {} - 1
# - gmtOffset - {} - -5
# - located_on - {'island': 'island-Little_Cayman'} - None
# airport {'city': 'city-George-Town-CAYM-CAYM', 'iatacode': 'GCM', 'country': 'CAYM'}
# - name - {} - Owen Roberts Intl
# - latitude - {} - 19.292778
# - longitude - {} - -81.35775
# - elevation - {} - 2
# - gmtOffset - {} - -5
# - located_on - {'island': 'island-GrandCayman'} - None
# airport {'country': 'CAYM', 'iatacode': 'CYB'}
# - name - {} - Gerrard Smith Intl
# - latitude - {} - 19.686981
# - longitude - {} - -79.882789
# - elevation - {} - 2
# - gmtOffset - {} - -5
# - located_on - {'island': 'island-Cayman_Brac'} - None
# airport {'city': 'cty-Central-African-Republic-Bangui', 'iatacode': 'BGF', 'country': 'RCA'}
# - name - {} - Bangui M Poko
# - latitude - {} - 4.398475
# - longitude - {} - 18.518786
# - elevation - {} - 368
# - gmtOffset - {} - 1
# airport {'city': 'cty-Chad-NDjamena', 'iatacode': 'NDJ', 'country': 'TCH'}
# - name - {} - Ndjamena Hassan Djamous
# - latitude - {} - 12.133689
# - longitude - {} - 15.034019
# - elevation - {} - 295
# - gmtOffset - {} - 1
# airport {'city': 'cty-Chile-2', 'iatacode': 'ANF', 'country': 'RCH'}
# - name - {} - Cerro Moreno Intl
# - latitude - {} - -23.444478
# - longitude - {} - -70.4451
# - elevation - {} - 139
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-14', 'iatacode': 'ZAL', 'country': 'RCH'}
# - name - {} - Pichoy
# - latitude - {} - -39.649956
# - longitude - {} - -73.086111
# - elevation - {} - 18
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-4', 'iatacode': 'LSC', 'country': 'RCH'}
# - name - {} - La Florida
# - latitude - {} - -29.916233
# - longitude - {} - -71.199522
# - elevation - {} - 147
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-3', 'iatacode': 'CPO', 'country': 'RCH'}
# - name - {} - Copiapo
# - latitude - {} - -27
# - longitude - {} - -70
# - elevation - {} - 305
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-8', 'iatacode': 'CCP', 'country': 'RCH'}
# - name - {} - Carriel Sur Intl
# - latitude - {} - -36.77265
# - longitude - {} - -73.063106
# - elevation - {} - 8
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-9', 'iatacode': 'ZCO', 'country': 'RCH'}
# - name - {} - Maquehue
# - latitude - {} - -38.766819
# - longitude - {} - -72.637097
# - elevation - {} - 93
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-13', 'iatacode': 'SCL', 'country': 'RCH'}
# - name - {} - Arturo Merino Benitez Intl
# - latitude - {} - -33.392975
# - longitude - {} - -70.785803
# - elevation - {} - 474
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-1', 'iatacode': 'IQQ', 'country': 'RCH'}
# - name - {} - Diego Aracena Intl
# - latitude - {} - -20.535222
# - longitude - {} - -70.181275
# - elevation - {} - 47
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-15', 'iatacode': 'ARI', 'country': 'RCH'}
# - name - {} - Chacalluta
# - latitude - {} - -18.348531
# - longitude - {} - -70.338742
# - elevation - {} - 51
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-10', 'iatacode': 'PMC', 'country': 'RCH'}
# - name - {} - El Tepual Intl
# - latitude - {} - -41.438886
# - longitude - {} - -73.093953
# - elevation - {} - 90
# - gmtOffset - {} - -4
# airport {'city': 'cty-Chile-12', 'iatacode': 'PUQ', 'country': 'RCH'}
# - name - {} - Carlos Ibanez Del Campo Intl
# - latitude - {} - -53.002642
# - longitude - {} - -70.854586
# - elevation - {} - 42
# - gmtOffset - {} - -4
# airport {'city': 'cty-China-29', 'iatacode': 'HGH', 'country': 'CN'}
# - name - {} - Xiaoshan
# - latitude - {} - 30.229503
# - longitude - {} - 120.434453
# - elevation - {} - 7
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-92', 'iatacode': 'XMN', 'country': 'CN'}
# - name - {} - Gaoqi
# - latitude - {} - 24.544036
# - longitude - {} - 118.127739
# - elevation - {} - 18
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-208', 'iatacode': 'HLD', 'country': 'CN'}
# - name - {} - Dongshan
# - latitude - {} - 49.204997
# - longitude - {} - 119.825
# - elevation - {} - 661
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-82', 'iatacode': 'XFN', 'country': 'CN'}
# - name - {} - Xiangfan Airport
# - latitude - {} - 32.1506
# - longitude - {} - 112.291
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-270', 'iatacode': 'XIC', 'country': 'CN'}
# - name - {} - Qingshan
# - latitude - {} - 27.989083
# - longitude - {} - 102.184361
# - elevation - {} - 1559
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-133', 'iatacode': 'HAK', 'country': 'CN'}
# - name - {} - Meilan
# - latitude - {} - 19.934856
# - longitude - {} - 110.458961
# - elevation - {} - 23
# - gmtOffset - {} - 8
# - located_on - {'island': 'island-Hainan'} - None
# airport {'city': 'cty-China-53', 'iatacode': 'HET', 'country': 'CN'}
# - name - {} - Baita Airport
# - latitude - {} - 40.851422
# - longitude - {} - 111.824103
# - elevation - {} - 1084
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-3', 'iatacode': 'PEK', 'country': 'CN'}
# - name - {} - Capital Intl
# - latitude - {} - 40.080111
# - longitude - {} - 116.584556
# - elevation - {} - 35
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-Shanghai', 'iatacode': 'PVG', 'country': 'CN'}
# - name - {} - Pudong
# - latitude - {} - 31.143378
# - longitude - {} - 121.805214
# - elevation - {} - 4
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-240', 'iatacode': 'WXN', 'country': 'CN'}
# - name - {} - Wanzhou Wuqiao Airport
# - latitude - {} - 30.8361
# - longitude - {} - 108.406
# - elevation - {} - 567
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-7', 'iatacode': 'WUH', 'country': 'CN'}
# - name - {} - Tianhe
# - latitude - {} - 30.783758
# - longitude - {} - 114.2081
# - elevation - {} - 34
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-46', 'iatacode': 'WUX', 'country': 'CN'}
# - name - {} - Wuxi Airport
# - latitude - {} - 31.4944
# - longitude - {} - 120.429
# - elevation - {} - 5
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-85', 'iatacode': 'WNZ', 'country': 'CN'}
# - name - {} - Wenzhou Longwan Airport
# - latitude - {} - 27.9122
# - longitude - {} - 120.852
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-101', 'iatacode': 'INC', 'country': 'CN'}
# - name - {} - Yinchuan
# - latitude - {} - 38.481944
# - longitude - {} - 106.009167
# - elevation - {} - 1098
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-228', 'iatacode': 'ZUH', 'country': 'CN'}
# - name - {} - Zhuhai Airport
# - latitude - {} - 22.0064
# - longitude - {} - 113.376
# - elevation - {} - 7
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-10', 'iatacode': 'HRB', 'country': 'CN'}
# - name - {} - Taiping
# - latitude - {} - 45.623403
# - longitude - {} - 126.250328
# - elevation - {} - 139
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-65', 'iatacode': 'JMU', 'country': 'CN'}
# - name - {} - Jiamusi Airport
# - latitude - {} - 46.843394
# - longitude - {} - 130.465389
# - elevation - {} - 80
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-17', 'iatacode': 'CGQ', 'country': 'CN'}
# - name - {} - Changchun
# - latitude - {} - 43.5412
# - longitude - {} - 125.1201
# - elevation - {} - 69
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-20', 'iatacode': 'CGO', 'country': 'CN'}
# - name - {} - Xinzheng
# - latitude - {} - 34.519672
# - longitude - {} - 113.840889
# - elevation - {} - 151
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-23', 'iatacode': 'LHW', 'country': 'CN'}
# - name - {} - Lanzhou Airport
# - latitude - {} - 36.117
# - longitude - {} - 103.617
# - elevation - {} - 1948
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-31', 'iatacode': 'SJW', 'country': 'CN'}
# - name - {} - Shijiazhuang Daguocun International Airport
# - latitude - {} - 38.280686
# - longitude - {} - 114.6973
# - elevation - {} - 71
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-9', 'iatacode': 'CKG', 'country': 'CN'}
# - name - {} - Jiangbei
# - latitude - {} - 29.719217
# - longitude - {} - 106.641678
# - elevation - {} - 416
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-30', 'iatacode': 'CSX', 'country': 'CN'}
# - name - {} - Huanghua
# - latitude - {} - 28.189158
# - longitude - {} - 113.219633
# - elevation - {} - 66
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-312', 'iatacode': 'BHY', 'country': 'CN'}
# - name - {} - Beihai Airport
# - latitude - {} - 21.5394
# - longitude - {} - 109.294
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-144', 'iatacode': 'TGO', 'country': 'CN'}
# - name - {} - Tongliao Airport
# - latitude - {} - 43.5567
# - longitude - {} - 122.2
# - elevation - {} - 730
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-28', 'iatacode': 'KHN', 'country': 'CN'}
# - name - {} - Changbei Intl
# - latitude - {} - 28.865
# - longitude - {} - 115.9
# - elevation - {} - 44
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-22', 'iatacode': 'KMG', 'country': 'CN'}
# - name - {} - Wujiaba
# - latitude - {} - 24.992364
# - longitude - {} - 102.743536
# - elevation - {} - 1895
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-5', 'iatacode': 'TSN', 'country': 'CN'}
# - name - {} - Binhai
# - latitude - {} - 39.124353
# - longitude - {} - 117.346183
# - elevation - {} - 3
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-35', 'iatacode': 'BAV', 'country': 'CN'}
# - name - {} - Baotou Airport
# - latitude - {} - 40.56
# - longitude - {} - 109.997
# - elevation - {} - 1013
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-26', 'iatacode': 'NDG', 'country': 'CN'}
# - name - {} - Qiqihar Sanjiazi Airport
# - latitude - {} - 47.239628
# - longitude - {} - 123.918131
# - elevation - {} - 145
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-41', 'iatacode': 'NNG', 'country': 'CN'}
# - name - {} - Wuxu
# - latitude - {} - 22.608267
# - longitude - {} - 108.172442
# - elevation - {} - 128
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-13', 'iatacode': 'NKG', 'country': 'CN'}
# - name - {} - Lukou
# - latitude - {} - 31.742042
# - longitude - {} - 118.862025
# - elevation - {} - 15
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-37', 'iatacode': 'URC', 'country': 'CN'}
# - name - {} - Diwopu
# - latitude - {} - 43.907106
# - longitude - {} - 87.474244
# - elevation - {} - 648
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-109', 'iatacode': 'NTG', 'country': 'CN'}
# - name - {} - Nantong Airport
# - latitude - {} - 32.0708
# - longitude - {} - 120.976
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-139', 'iatacode': 'MIG', 'country': 'CN'}
# - name - {} - Mianyang Airport
# - latitude - {} - 31.4281
# - longitude - {} - 104.741
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-19', 'iatacode': 'TYN', 'country': 'CN'}
# - name - {} - Wusu
# - latitude - {} - 37.746897
# - longitude - {} - 112.628428
# - elevation - {} - 785
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-8', 'iatacode': 'CAN', 'country': 'CN'}
# - name - {} - Baiyun Intl
# - latitude - {} - 23.392436
# - longitude - {} - 113.298786
# - elevation - {} - 15
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-140', 'iatacode': 'LZO', 'country': 'CN'}
# - name - {} - Luzhou Airport
# - latitude - {} - 28.8522
# - longitude - {} - 105.393
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-112', 'iatacode': 'LYI', 'country': 'CN'}
# - name - {} - Shubuling Airport
# - latitude - {} - 35.0461
# - longitude - {} - 118.412
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-324', 'iatacode': 'LXA', 'country': 'CN'}
# - name - {} - Lhasa-Gonggar
# - latitude - {} - 29.297778
# - longitude - {} - 90.911944
# - elevation - {} - 4005
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-286', 'iatacode': 'WEH', 'country': 'CN'}
# - name - {} - Weihai Airport
# - latitude - {} - 37.1871
# - longitude - {} - 122.229
# - elevation - {} - 44
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-57', 'iatacode': 'MDG', 'country': 'CN'}
# - name - {} - Mudanjiang
# - latitude - {} - 44.523889
# - longitude - {} - 129.568889
# - elevation - {} - 269
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-15', 'iatacode': 'DLC', 'country': 'CN'}
# - name - {} - Zhoushuizi
# - latitude - {} - 38.965667
# - longitude - {} - 121.5386
# - elevation - {} - 33
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-16', 'iatacode': 'TNA', 'country': 'CN'}
# - name - {} - Jinan
# - latitude - {} - 36.857214
# - longitude - {} - 117.215992
# - elevation - {} - 23
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-332', 'iatacode': 'SYX', 'country': 'CN'}
# - name - {} - Phoenix International
# - latitude - {} - 18.302897
# - longitude - {} - 109.412272
# - elevation - {} - 28
# - gmtOffset - {} - 8
# - located_on - {'island': 'island-Hainan'} - None
# airport {'city': 'cty-China-21', 'iatacode': 'KWE', 'country': 'CN'}
# - name - {} - Longdongbao
# - latitude - {} - 26.538522
# - longitude - {} - 106.800703
# - elevation - {} - 1139
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-105', 'iatacode': 'SZX', 'country': 'CN'}
# - name - {} - Baoan Intl
# - latitude - {} - 22.639258
# - longitude - {} - 113.810664
# - elevation - {} - 4
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-11', 'iatacode': 'CTU', 'country': 'CN'}
# - name - {} - Shuangliu
# - latitude - {} - 30.578528
# - longitude - {} - 103.947086
# - elevation - {} - 495
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-157', 'iatacode': 'YNJ', 'country': 'CN'}
# - name - {} - Yanji Airport
# - latitude - {} - 42.8828
# - longitude - {} - 129.451258
# - elevation - {} - 190
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-72', 'iatacode': 'YNT', 'country': 'CN'}
# - name - {} - Laishan
# - latitude - {} - 37.401667
# - longitude - {} - 121.371667
# - elevation - {} - 18
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-126', 'iatacode': 'YNZ', 'country': 'CN'}
# - name - {} - Yancheng Airport
# - latitude - {} - 33.3856
# - longitude - {} - 120.125
# - elevation - {} - None
# - gmtOffset - {} - 8
# airport {'city': 'cty-China-91', 'iatacode': 'YIH', 'country': 'CN'}
# - name - {} - Yichang Airport
# ...
# - longitude - {} - -106.6091944
# - elevation - {} - 1633
# - gmtOffset - {} - -7
# airport {'city': 'cty-United-States-7', 'iatacode': 'SAN', 'country': 'USA'}
# - name - {} - San Diego Intl
# - latitude - {} - 32.733556
# - longitude - {} - -117.189667
# - elevation - {} - 5
# - gmtOffset - {} - -8
# airport {'city': 'cty-United-States-9', 'iatacode': 'SAT', 'country': 'USA'}
# - name - {} - San Antonio Intl
# - latitude - {} - 29.533694
# - longitude - {} - -98.469778
# - elevation - {} - 247
# - gmtOffset - {} - -6
# airport {'city': 'cty-Georgia-Savannah', 'iatacode': 'SAV', 'country': 'USA'}
# - name - {} - Savannah Hilton Head Intl
# - latitude - {} - 32.127583
# - longitude - {} - -81.202139
# - elevation - {} - 16
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-28', 'iatacode': 'PWM', 'country': 'USA'}
# - name - {} - Portland Intl Jetport
# - latitude - {} - 43.646161
# - longitude - {} - -70.309281
# - elevation - {} - 23
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-122', 'iatacode': 'PVD', 'country': 'USA'}
# - name - {} - Theodore Francis Green State
# - latitude - {} - 41.732581
# - longitude - {} - -71.420383
# - elevation - {} - 17
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-13', 'iatacode': 'IND', 'country': 'USA'}
# - name - {} - Indianapolis Intl
# - latitude - {} - 39.717331
# - longitude - {} - -86.294383
# - elevation - {} - 243
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-22', 'iatacode': 'IAD', 'country': 'USA'}
# - name - {} - Washington Dulles Intl
# - latitude - {} - 38.944533
# - longitude - {} - -77.455811
# - elevation - {} - 95
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-5', 'iatacode': 'IAH', 'country': 'USA'}
# - name - {} - George Bush Intcntl Houston
# - latitude - {} - 29.984433
# - longitude - {} - -95.341442
# - elevation - {} - 30
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-53', 'iatacode': 'ICT', 'country': 'USA'}
# - name - {} - Wichita Mid Continent
# - latitude - {} - 37.649944
# - longitude - {} - -97.433056
# - elevation - {} - 406
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-5', 'iatacode': 'HOU', 'country': 'USA'}
# - name - {} - William P Hobby
# - latitude - {} - 29.645419
# - longitude - {} - -95.278889
# - elevation - {} - 14
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-74', 'iatacode': 'ROC', 'country': 'USA'}
# - name - {} - Greater Rochester Intl
# - latitude - {} - 43.118866
# - longitude - {} - -77.672389
# - elevation - {} - 170
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-124', 'iatacode': 'FLL', 'country': 'USA'}
# - name - {} - Fort Lauderdale Hollywood Intl
# - latitude - {} - 26.072583
# - longitude - {} - -80.15275
# - elevation - {} - 3
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-46', 'iatacode': 'OMA', 'country': 'USA'}
# - name - {} - Eppley Afld
# - latitude - {} - 41.303167
# - longitude - {} - -95.894069
# - elevation - {} - 300
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-28', 'iatacode': 'PDX', 'country': 'USA'}
# - name - {} - Portland Intl
# - latitude - {} - 45.588722
# - longitude - {} - -122.5975
# - elevation - {} - 9
# - gmtOffset - {} - -8
# airport {'city': 'cty-United-States-71', 'iatacode': 'ORF', 'country': 'USA'}
# - name - {} - Norfolk Intl
# - latitude - {} - 36.894611
# - longitude - {} - -76.201222
# - elevation - {} - 8
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-4', 'iatacode': 'ORD', 'country': 'USA'}
# - name - {} - Chicago Ohare Intl
# - latitude - {} - 41.978603
# - longitude - {} - -87.904842
# - elevation - {} - 204
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-145', 'iatacode': 'FNT', 'country': 'USA'}
# - name - {} - Bishop International
# - latitude - {} - 42.965424
# - longitude - {} - -83.743629
# - elevation - {} - 238
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-8', 'iatacode': 'PHX', 'country': 'USA'}
# - name - {} - Phoenix Sky Harbor Intl
# - latitude - {} - 33.434278
# - longitude - {} - -112.011583
# - elevation - {} - 346
# - gmtOffset - {} - -7
# airport {'city': 'cty-United-States-49', 'iatacode': 'PIT', 'country': 'USA'}
# - name - {} - Pittsburgh Intl
# - latitude - {} - 40.491467
# - longitude - {} - -80.232872
# - elevation - {} - 367
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-Pierre', 'iatacode': 'PIR', 'country': 'USA'}
# - name - {} - Pierre Regional Airport
# - latitude - {} - 44.3827
# - longitude - {} - -100.286
# - elevation - {} - 531
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-6', 'iatacode': 'PHL', 'country': 'USA'}
# - name - {} - Philadelphia Intl
# - latitude - {} - 39.871944
# - longitude - {} - -75.241139
# - elevation - {} - 11
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-Helena', 'iatacode': 'HLN', 'country': 'USA'}
# - name - {} - Helena Rgnl
# - latitude - {} - 46.606806
# - longitude - {} - -111.98275
# - elevation - {} - 1182
# - gmtOffset - {} - -7
# airport {'city': 'cty-United-States-96', 'iatacode': 'GEG', 'country': 'USA'}
# - name - {} - Spokane Intl
# - latitude - {} - 47.619861
# - longitude - {} - -117.533833
# - elevation - {} - 724
# - gmtOffset - {} - -8
# airport {'city': 'cty-United-States-31', 'iatacode': 'OKC', 'country': 'USA'}
# - name - {} - Will Rogers World
# - latitude - {} - 35.393089
# - longitude - {} - -97.600733
# - elevation - {} - 395
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-81', 'iatacode': 'RIC', 'country': 'USA'}
# - name - {} - Richmond Intl
# - latitude - {} - 37.505167
# - longitude - {} - -77.319667
# - elevation - {} - 51
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-2', 'iatacode': 'JFK', 'country': 'USA'}
# - name - {} - John F Kennedy Intl
# - latitude - {} - 40.639751
# - longitude - {} - -73.778925
# - elevation - {} - 4
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-15', 'iatacode': 'JAX', 'country': 'USA'}
# - name - {} - Jacksonville Intl
# - latitude - {} - 30.494056
# - longitude - {} - -81.687861
# - elevation - {} - 9
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-87', 'iatacode': 'JAN', 'country': 'USA'}
# - name - {} - Jackson Evers Intl
# - latitude - {} - 32.311167
# - longitude - {} - -90.075889
# - elevation - {} - 105
# - gmtOffset - {} - -6
# airport {'city': 'cty-United-States-Santa-Fe', 'iatacode': 'SAF', 'country': 'USA'}
# - name - {} - Santa Fe Muni
# - latitude - {} - 35.617108
# - longitude - {} - -106.089422
# - elevation - {} - 1935
# - gmtOffset - {} - -7
# airport {'city': 'cty-United-States-15', 'iatacode': 'OAJ', 'country': 'USA'}
# - name - {} - Albert J Ellis
# - latitude - {} - 34.829164
# - longitude - {} - -77.612139
# - elevation - {} - 29
# - gmtOffset - {} - -5
# airport {'city': 'cty-United-States-44', 'iatacode': 'OAK', 'country': 'USA'}
# - name - {} - Metropolitan Oakland Intl
# - latitude - {} - 37.721278
# - longitude - {} - -122.220722
# - elevation - {} - 3
# - gmtOffset - {} - -8
# airport {'city': 'cty-United-States-Juneau', 'iatacode': 'JNU', 'country': 'USA'}
# - name - {} - Juneau Intl
# - latitude - {} - 58.354972
# - longitude - {} - -134.576278
# - elevation - {} - 6
# - gmtOffset - {} - -9
# airport {'city': 'cty-United-States-67', 'iatacode': 'ANC', 'country': 'USA'}
# - name - {} - Ted Stevens Anchorage Intl
# - latitude - {} - 61.174361
# - longitude - {} - -149.996361
# - elevation - {} - 46
# - gmtOffset - {} - -9
# airport {'city': 'cty-United-States-36', 'iatacode': 'HNL', 'country': 'USA'}
# - name - {} - Honolulu Intl
# - latitude - {} - 21.318681
# - longitude - {} - -157.922428
# - elevation - {} - 4
# - gmtOffset - {} - -10
# - located_on - {'island': 'island-Oahu'} - None
# airport {'city': 'stadt-Hilo-USA-HI', 'iatacode': 'ITO', 'country': 'USA'}
# - name - {} - Hilo Intl
# - latitude - {} - 19.721375
# - longitude - {} - -155.048469
# - elevation - {} - 12
# - gmtOffset - {} - -10
# - located_on - {'island': 'island-Hawaii'} - None
# airport {'country': 'USA', 'iatacode': 'LNY'}
# - name - {} - Lanai
# - latitude - {} - 20.785611
# - longitude - {} - -156.951419
# - elevation - {} - 399
# - gmtOffset - {} - -10
# - located_on - {'island': 'island-Lanai'} - None
# airport {'country': 'USA', 'iatacode': 'MKK'}
# - name - {} - Molokai
# - latitude - {} - 21.152886
# - longitude - {} - -157.096256
# - elevation - {} - 138
# - gmtOffset - {} - -10
# - located_on - {'island': 'island-Molokai'} - None
# airport {'country': 'USA', 'iatacode': 'OGG'}
# - name - {} - Kahului
# - latitude - {} - 20.89865
# - longitude - {} - -156.430458
# - elevation - {} - 16
# - gmtOffset - {} - -10
# - located_on - {'island': 'island-Maui'} - None
# airport {'city': 'cty-Uruguay-Montevideo', 'iatacode': 'MVD', 'country': 'ROU'}
# - name - {} - Carrasco Intl
# - latitude - {} - -34.838417
# - longitude - {} - -56.030806
# - elevation - {} - 32
# - gmtOffset - {} - -3
# airport {'city': 'cty-Uzbekistan-6', 'iatacode': 'BHK', 'country': 'UZB'}
# - name - {} - Bukhara
# - latitude - {} - 39.775
# - longitude - {} - 64.483333
# - elevation - {} - 229
# - gmtOffset - {} - 5
# airport {'city': 'cty-Uzbekistan-13', 'iatacode': 'UGC', 'country': 'UZB'}
# - name - {} - Urgench Airport
# - latitude - {} - 41.5843
# - longitude - {} - 60.6417
# - elevation - {} - 98
# - gmtOffset - {} - 5
# airport {'city': 'cty-Uzbekistan-Termiz', 'iatacode': 'TMJ', 'country': 'UZB'}
# - name - {} - Termez Airport
# - latitude - {} - 37.286667
# - longitude - {} - 67.31
# - elevation - {} - 313
# - gmtOffset - {} - 5
# airport {'city': 'cty-Uzbekistan-Tashkent', 'iatacode': 'TAS', 'country': 'UZB'}
# - name - {} - Yuzhny
# - latitude - {} - 41.257861
# - longitude - {} - 69.281186
# - elevation - {} - 432
# - gmtOffset - {} - 5
# airport {'city': 'cty-Uzbekistan-9', 'iatacode': 'NCU', 'country': 'UZB'}
# - name - {} - Nukus Airport
# - latitude - {} - 42.4884
# - longitude - {} - 59.6233
# - elevation - {} - 75
# - gmtOffset - {} - 5
# airport {'city': 'cty-Uzbekistan-7', 'iatacode': 'FEG', 'country': 'UZB'}
# - name - {} - Fergana Airport
# - latitude - {} - 40.3588
# - longitude - {} - 71.745
# - elevation - {} - 604
# - gmtOffset - {} - 5
# airport {'city': 'cty-Uzbekistan-3', 'iatacode': 'SKD', 'country': 'UZB'}
# - name - {} - Samarkand
# - latitude - {} - 39.700547
# - longitude - {} - 66.983829
# - elevation - {} - 678
# - gmtOffset - {} - 5
# airport {'city': 'cty-Vanuatu-Port-Vila', 'iatacode': 'VLI', 'country': 'VU'}
# - name - {} - Port Vila Bauerfield
# - latitude - {} - -17.699325
# - longitude - {} - 168.319794
# - elevation - {} - 21
# - gmtOffset - {} - 11
# - located_on - {'island': 'island-Efate'} - None
# airport {'city': 'cty-Venezuela-6', 'iatacode': 'PZO', 'country': 'YV'}
# - name - {} - General Manuel Carlos Piar
# - latitude - {} - 8.288528
# - longitude - {} - -62.760361
# - elevation - {} - 144
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-10', 'iatacode': 'BLA', 'country': 'YV'}
# - name - {} - General Jose Antonio Anzoategui Intl
# - latitude - {} - 10.107139
# - longitude - {} - -64.689161
# - elevation - {} - 8
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-Puerto-Ayacucho', 'iatacode': 'PYH', 'country': 'YV'}
# - name - {} - Casique Aramare
# - latitude - {} - 5.619992
# - longitude - {} - -67.606103
# - elevation - {} - 75
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-19', 'iatacode': 'BNS', 'country': 'YV'}
# - name - {} - Barinas
# - latitude - {} - 8.619575
# - longitude - {} - -70.220825
# - elevation - {} - 203
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-5', 'iatacode': 'BRM', 'country': 'YV'}
# - name - {} - Barquisimeto Intl
# - latitude - {} - 10.042747
# - longitude - {} - -69.358619
# - elevation - {} - 623
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-Maracaibo', 'iatacode': 'MAR', 'country': 'YV'}
# - name - {} - La Chinita Intl
# - latitude - {} - 10.558208
# - longitude - {} - -71.727856
# - elevation - {} - 72
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-4', 'iatacode': 'VLN', 'country': 'YV'}
# - name - {} - Arturo Michelena Intl
# - latitude - {} - 10.149733
# - longitude - {} - -67.9284
# - elevation - {} - 432
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-13', 'iatacode': 'MUN', 'country': 'YV'}
# - name - {} - Maturin
# - latitude - {} - 9.749067
# - longitude - {} - -63.1534
# - elevation - {} - 68
# - gmtOffset - {} - -4
# airport {'city': 'cty-Venezuela-Caracas', 'iatacode': 'CCS', 'country': 'YV'}
# - name - {} - Simon Bolivar Intl
# - latitude - {} - 10.603117
# - longitude - {} - -66.990583
# - elevation - {} - 72
# - gmtOffset - {} - -4
# airport {'city': 'cty-Vietnam-20', 'iatacode': 'VKG', 'country': 'VN'}
# - name - {} - Rach Gia
# - latitude - {} - 9.949676
# - longitude - {} - 105.133659
# - elevation - {} - 2
# - gmtOffset - {} - 7
# airport {'city': 'cty-Vietnam-18', 'iatacode': 'VII', 'country': 'VN'}
# - name - {} - Vinh Airport
# - latitude - {} - 18.737569
# - longitude - {} - 105.670764
# - elevation - {} - 7
# - gmtOffset - {} - 7
# airport {'city': 'cty-Vietnam-2', 'iatacode': 'SGN', 'country': 'VN'}
# - name - {} - Tansonnhat Intl
# - latitude - {} - 10.818797
# - longitude - {} - 106.651856
# - elevation - {} - 10
# - gmtOffset - {} - 7
# airport {'city': 'cty-Vietnam-Hanoi', 'iatacode': 'HAN', 'country': 'VN'}
# - name - {} - Noibai Intl
# - latitude - {} - 21.221192
# - longitude - {} - 105.807178
# - elevation - {} - 12
# - gmtOffset - {} - 7
# airport {'city': 'cty-Vietnam-4', 'iatacode': 'HPH', 'country': 'VN'}
# - name - {} - Cat Bi International Airport
# - latitude - {} - 20.819386
# - longitude - {} - 106.724989
# - elevation - {} - 2
# - gmtOffset - {} - 7
# airport {'city': 'cty-Vietnam-6', 'iatacode': 'VCA', 'country': 'VN'}
# - name - {} - Tra Noc Airport
# - latitude - {} - 10.085119
# - longitude - {} - 105.711922
# - elevation - {} - 3
# - gmtOffset - {} - 7
# airport {'city': 'cty-Vietnam-7', 'iatacode': 'NHA', 'country': 'VN'}
# - name - {} - Nha Trang
# - latitude - {} - 12.227467
# - longitude - {} - 109.192322
# - elevation - {} - 6
# - gmtOffset - {} - 7
# airport {'city': 'cty-VIRG-Charlotte-Amalie', 'iatacode': 'STT', 'country': 'VIRG'}
# - name - {} - Cyril E King
# - latitude - {} - 18.337306
# - longitude - {} - -64.973361
# - elevation - {} - 7
# - gmtOffset - {} - -4
# - located_on - {'island': 'island-SaintThomas'} - None
# airport {'city': 'city-Mata-Utu-WAFU-WAFU', 'iatacode': 'WLS', 'country': 'WAFU'}
# - name - {} - Wallis
# - latitude - {} - -13.238281
# - longitude - {} - -176.199228
# - elevation - {} - 24
# - gmtOffset - {} - 12
# - located_on - {'island': 'island-Uvea'} - None
# airport {'city': 'stadt-El_Aaiun-DARS-DARS', 'iatacode': 'EUN', 'country': 'WSA'}
# - name - {} - Hassan I Airport
# - latitude - {} - 27.1517
# - longitude - {} - -13.2192
# - elevation - {} - 63
# - gmtOffset - {} - 0
# airport {'city': 'cty-Yemen-Sanaa', 'iatacode': 'SAH', 'country': 'YE'}
# - name - {} - Sanaa Intl
# - latitude - {} - 15.476258
# - longitude - {} - 44.219739
# - elevation - {} - 2200
# - gmtOffset - {} - 3
# airport {'city': 'cty-Yemen-Hodeida', 'iatacode': 'HOD', 'country': 'YE'}
# - name - {} - Hodeidah Intl
# - latitude - {} - 14.753
# - longitude - {} - 42.976336
# - elevation - {} - 13
# - gmtOffset - {} - 3
# airport {'city': 'cty-Yemen-Taiz', 'iatacode': 'TAI', 'country': 'YE'}
# - name - {} - Taiz Intl
# - latitude - {} - 13.685964
# - longitude - {} - 44.139056
# - elevation - {} - 1475
# - gmtOffset - {} - 3
# airport {'city': 'cty-Yemen-Aden', 'iatacode': 'ADE', 'country': 'YE'}
# - name - {} - Aden Intl
# - latitude - {} - 12.829542
# - longitude - {} - 45.028792
# - elevation - {} - 2
# - gmtOffset - {} - 3
# airport {'city': 'cty-Zambia-Livingstone', 'iatacode': 'LVI', 'country': 'Z'}
# - name - {} - Livingstone
# - latitude - {} - -17.821756
# - longitude - {} - 25.822692
# - elevation - {} - 1007
# - gmtOffset - {} - 2
# airport {'city': 'cty-Zambia-3', 'iatacode': 'NLA', 'country': 'Z'}
# - name - {} - Ndola
# - latitude - {} - -12.998139
# - longitude - {} - 28.664944
# - elevation - {} - 1270
# - gmtOffset - {} - 2
# airport {'city': 'cty-Zambia-2', 'iatacode': 'LUN', 'country': 'Z'}
# - name - {} - Lusaka Intl
# - latitude - {} - -15.330817
# - longitude - {} - 28.452628
# - elevation - {} - 1152
# - gmtOffset - {} - 2
# airport {'city': 'cty-Zimbabwe-2', 'iatacode': 'BUQ', 'country': 'ZW'}
# - name - {} - J M Nkomo Intl
# - latitude - {} - -20.017431
# - longitude - {} - 28.617869
# - elevation - {} - 1329
# - gmtOffset - {} - 2
# airport {'city': 'cty-Zimbabwe-1', 'iatacode': 'HRE', 'country': 'ZW'}
# - name - {} - Harare Intl
# - latitude - {} - -17.931806
# - longitude - {} - 31.092847
# - elevation - {} - 1490
# - gmtOffset - {} - 2
